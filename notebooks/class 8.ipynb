# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.
# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %%
import math

def area(radius):
    """Calculate the area of a circle."""
    return math.pi * radius ** 2

total = area(5) + area(3)
print(area(5))
a = area(5)
print(a)
print(total)
# Out:
# 78.53981633974483
# 78.53981633974483
# 106.81415022205297

# %%
x=int(input("Enter value of x"))
if 0 < x < 10:
    print('x is a positive single-digit number.')
else:
    print('x is not a positive single-digit number')
# Out:
# x is not a positive single-digit number

# %%
def distance(x1, y1, x2, y2):
    return 0.0  # placeholder — fake it till you make it!

def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    print(f"dx = {dx}, dy = {dy}")  # temporary
    return 0.0
def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    print(f"dx = {dx}, dy = {dy}")  # temporary
    return 0.0
def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return (dx**2 + dy**2) ** 0.5

distance(5, 10, 20, 15)
# Out:
# 15.811388300841896

# %%
def circle_area(radius):
    import math
    return math.pi * radius ** 2


def ring_area(outer, inner):
    """Area of a ring (donut shape)."""
    return circle_area(outer) - circle_area(inner)

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import math

outer, inner = 5, 3

fig, ax = plt.subplots(figsize=(6, 6))

# draw outer circle
outer_circle = patches.Circle((0, 0), outer, color='#4a90d9', alpha=0.3, label=f'Outer (r={outer})')
ax.add_patch(outer_circle)

# draw ring area
ring = patches.Annulus((0, 0), outer, outer - inner, color='#7cd98a', alpha=0.5, label=f'Ring area = {ring_area(outer, inner):.2f}')
ax.add_patch(ring)

# draw inner circle
inner_circle = patches.Circle((0, 0), inner, color='#e06060', alpha=0.2, label=f'Inner (r={inner})')
ax.add_patch(inner_circle)

ax.set_xlim(-7, 7)
ax.set_ylim(-7, 7)
ax.set_aspect('equal')
ax.legend(loc='upper right')
ax.set_title('Ring Area Visualization')
ax.grid(True, alpha=0.3)
plt.show()

# %%
def is_triangle(x, y, z):
    if x+y<z:
        print("Triangle cannot be formed")
    elif x+z<y:
        print("Triangle cannot be formed")
    elif y+z<x:
        print("Triangle cannot be formed")
    else:
        print("Triangle can be formed")

is_triangle(10, 15, 20)
# Out:
# Triangle can be formed

# %%
def recurse(n, s):
    if n == 0:
        print(s)
    else:
        recurse(n-1, n+s)

recurse(3, 1)
import matplotlib.pyplot as plt

frames = [
    ("__main__", ""),
    ("recurse", "n=3, s=0"),
    ("recurse", "n=2, s=3"),
    ("recurse", "n=1, s=5"),
    ("recurse", "n=0, s=6  ← prints 6"),
]

fig, ax = plt.subplots(figsize=(6, len(frames) * 0.8 + 1))
for i, (name, vars_) in enumerate(reversed(frames)):
    y = i
    ax.add_patch(plt.Rectangle((0.5, y), 4, 0.7, fill=True, 
                 facecolor='#d4e6f1' if name == '__main__' else '#d5f5e3',
                 edgecolor='#333', linewidth=1.5))
    ax.text(0.7, y + 0.35, name, fontsize=12, fontweight='bold', va='center')
    ax.text(2.5, y + 0.35, vars_, fontsize=11, va='center', color='#333')

ax.set_xlim(0, 5.5)
ax.set_ylim(-0.3, len(frames) * 1.0 + 0.3)
ax.set_aspect('equal')
ax.axis('off')
ax.set_title('Stack Diagram at print(s)', fontsize=14, pad=15)
plt.tight_layout()
plt.show()
# Out:
# 7

# %%
from time import time

now = time()
now
